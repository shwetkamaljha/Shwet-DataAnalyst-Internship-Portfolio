# %% [markdown]
# # ApexPlanet Internship - Task 1
# ## Data Immersion and Wrangling
#
# ### Business Objective
# The goal of this task is to analyze a real-world retail sales dataset, identify data quality issues, and transform the raw data into a clean and structured format for business intelligence, dashboarding, and future advanced analytics tasks.

# %%
import pandas as pd

# %% [markdown]
# ### ***Data Loading***

# %%
url = "https://drive.google.com/uc?export=download&id=17rL61-WJcSiEtB7fYfCDxdCzWwjtgXai"

# %%
df = pd.read_csv(url, encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# **Initial Profiling**

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe(include="all")
# Out:
#              Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# count   9994.000000            9994       9994        9994            9994
# unique          NaN            5009       1237        1334               4
# top             NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq            NaN              14         38          35            5968
# mean    4997.500000             NaN        NaN         NaN             NaN
# std     2885.163629             NaN        NaN         NaN             NaN
# min        1.000000             NaN        NaN         NaN             NaN
# 25%     2499.250000             NaN        NaN         NaN             NaN
# 50%     4997.500000             NaN        NaN         NaN             NaN
# 75%     7495.750000             NaN        NaN         NaN             NaN
# max     9994.000000             NaN        NaN         NaN             NaN
#
# ...

# %% [markdown]
# **Data Dictionary**

# %%
data_dictionary = pd.DataFrame({
    "Column_Name": df.columns,
    "Data_Type": df.dtypes.astype(str),
    "Missing_Values": df.isnull().sum().values,
    "Unique_Values": df.nunique().values
})

data_dictionary
# Out:
#                  Column_Name Data_Type  Missing_Values  Unique_Values
# Row ID                Row ID     int64               0           9994
# Order ID            Order ID    object               0           5009
# Order Date        Order Date    object               0           1237
# Ship Date          Ship Date    object               0           1334
# Ship Mode          Ship Mode    object               0              4
# Customer ID      Customer ID    object               0            793
# Customer Name  Customer Name    object               0            793
# Segment              Segment    object               0              3
# Country              Country    object               0              1
# City                    City    object               0            531
# State                  State    object               0             49
# Postal Code      Postal Code     int64               0            631
# ...

# %%
data_dictionary.to_csv("task1_data_dictionary.csv", index=False)

# %% [markdown]
# **Quality Assessment**

# %%
missing_values = df.isnull().sum().sort_values(ascending=False)
missing_values
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_report = pd.DataFrame({
    "Missing_Count": missing_values,
    "Missing_Percent": missing_percent
}).sort_values("Missing_Percent", ascending=False)

missing_report
# Out:
#                Missing_Count  Missing_Percent
# Row ID                     0              0.0
# Order ID                   0              0.0
# Order Date                 0              0.0
# Ship Date                  0              0.0
# Ship Mode                  0              0.0
# Customer ID                0              0.0
# Customer Name              0              0.0
# Segment                    0              0.0
# Country                    0              0.0
# City                       0              0.0
# State                      0              0.0
# Postal Code                0              0.0
# Region                     0              0.0
# Product ID                 0              0.0
# Category                   0              0.0
# Sub-Category               0              0.0
# Product Name               0              0.0
# Sales                      0              0.0
# Quantity                   0              0.0
# ...

# %% [markdown]
# **Cleaning**

# %%
duplicate_rows = df.duplicated().sum()
print("Duplicate Rows:", duplicate_rows)
# Out:
# Duplicate Rows: 0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()
print("Duplicates removed successfully")
# Out:
# Duplicates removed successfully

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_").str.replace("-", "_")
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
df["order_date"] = pd.to_datetime(df["order_date"])
df["ship_date"] = pd.to_datetime(df["ship_date"])

# %%
df["delivery_days"] = (df["ship_date"] - df["order_date"]).dt.days
df["profit_margin"] = (df["profit"] / df["sales"]) * 100

df["sales_bucket"] = pd.cut(
    df["sales"],
    bins=[0, 100, 500, 1000, 5000],
    labels=["Low", "Medium", "High", "Very High"]
)

df.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           category  sub_category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
df.to_csv("task1_cleaned_superstore.csv", index=False)
print("Cleaned dataset saved successfully")
# Out:
# Cleaned dataset saved successfully

# %% [markdown]
# ## Conclusion
# In this task, the Superstore retail dataset was successfully loaded and profiled to understand its structure, business fields, and data quality. The dataset contained **9,994 rows and 21 columns**, providing a strong foundation for retail sales analytics.
#
# A complete data dictionary was created to document each column’s datatype, uniqueness, and completeness. During the data quality assessment phase, the dataset was found to have **no missing values and no duplicate records**, indicating strong source-level consistency.
#
# Further, the dataset was cleaned by standardizing column names and converting `order_date` and `ship_date` into proper datetime format. To make the dataset more business-ready, additional features such as **delivery_days, profit_margin, and sales_bucket** were engineered to support logistics analysis, profitability tracking, and sales segmentation.
#
# Finally, the transformed dataset was exported successfully as a cleaned CSV file and is now fully prepared for **EDA, SQL-based business analysis, and dashboard development in the next task**.
